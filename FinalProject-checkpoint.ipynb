# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels
from scipy import stats
from scipy.stats import boxcox
import scipy
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison
from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.proportion import proportions_chisquare

# %% [markdown]
# # load dataset

# %%
SolarPrices = pd.read_csv('C:/Users/arica/OneDrive/Desktop/course work/FinalProject/Week2/StatePricePower.csv')

# %%
SolarPrices.head()
# Out:
#   Data_Status State    MSN   2010   2011   2012   2013   2014   2015   2016  \
# 0       2020P    NJ  ARICD  13.09  15.74  16.41  15.15  15.62  13.28   8.63
# 1       2020P    NJ  ARTCD  13.09  15.74  16.41  15.15  15.62  13.28   8.63
# 2       2020P    NJ  ARTXD  13.09  15.74  16.41  15.15  15.62  13.28   8.63
# 3       2020P    NJ  AVACD  25.19  31.64  33.04  32.71  33.16  24.86  21.62
# 4       2020P    NJ  AVTCD  25.19  31.64  33.04  32.71  33.16  24.86  21.62
#
#     2017   2018   2019
# 0   9.98  13.34  13.05
# 1   9.98  13.34  13.05
# 2   9.98  13.34  13.05
# 3  24.13  27.04  25.57
# 4  24.13  27.04  25.57

# %% [markdown]
# # We are running the pairplot to see the diffent prices for different types of energy and on the last decade from 2010 to 2019 as per the dataset

# %%
sns.pairplot(SolarPrices)

# %%
SolarPrices2 = pd.read_excel('C:/Users/arica/OneDrive/Desktop/course work/FinalProject/Week1/epa_03_02_a.xlsx')

# %%
columns = SolarPrices2.iloc[2,:].values

# %%
SolarPricesAnnual = SolarPrices2.iloc[4:15,:]

# %%
SolarPricesAnnual.columns = columns

# %%
import matplotlib.pyplot as plt

# %%
SolarPricesAnnual['Solar'].plot()
plt.xticks(SolarPricesAnnual.index, SolarPricesAnnual["Period"].values)
# Out:
# ([<matplotlib.axis.XTick at 0x1114ff292e0>,
# ...
#  [Text(4, 0, '2010'),
#   Text(5, 0, '2011'),
#   Text(6, 0, '2012'),
#   Text(7, 0, '2013'),
#   Text(8, 0, '2014'),
#   Text(9, 0, '2015'),
#   Text(10, 0, '2016'),
#   Text(11, 0, '2017'),
#   Text(12, 0, '2018'),
#   Text(13, 0, '2019'),
#   Text(14, 0, '2020')])
